# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
# Out:
# 2024-05-06 03:39:51.564766: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-06 03:39:51.564865: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-06 03:39:51.716019: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
tf.random.set_seed(5001)

# %%
train_df = pd.read_csv('/kaggle/input/human-activity-recognition-with-smartphones/train.csv')
test_df = pd.read_csv('/kaggle/input/human-activity-recognition-with-smartphones/test.csv')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
train_df
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# 1            -0.998245         -0.975300         -0.960322         -0.998807
# 2            -0.995380         -0.967187         -0.978944         -0.996520
# 3            -0.996091         -0.983403         -0.990675         -0.997099
# 4            -0.998139         -0.980817         -0.990482         -0.998321
# ...                ...               ...               ...               ...
# 7347         -0.195387          0.039905          0.077078         -0.282301
# 7348         -0.235309          0.004816          0.059280         -0.322552
# 7349         -0.218218         -0.103822          0.274533         -0.304515
# 7350         -0.219139         -0.111412          0.268893         -0.310487
# 7351         -0.269270         -0.087212          0.177404         -0.377404
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 0            -0.983185         -0.923527         -0.934724  ...
# 1            -0.974914         -0.957686         -0.943068  ...
# 2            -0.963668         -0.977469         -0.938692  ...
# 3            -0.982750         -0.989302         -0.938692  ...
# 4            -0.979672         -0.990441         -0.942469  ...
# ...                ...               ...               ...  ...
# 7347          0.043616          0.060410          0.210795  ...
# 7348         -0.029456          0.080585          0.117440  ...
# 7349         -0.098913          0.332584          0.043999  ...
# 7350         -0.068200          0.319473          0.101702  ...
# 7351         -0.038678          0.229430          0.269013  ...
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                           -0.710304                    -0.112754
# 1                           -0.861499                     0.053477
# 2                           -0.760104                    -0.118559
# 3                           -0.482845                    -0.036788
# 4                           -0.699205                     0.123320
# ...                               ...                          ...
# 7347                        -0.880324                    -0.190437
# 7348                        -0.680744                     0.064907
# 7349                        -0.304029                     0.052806
# 7350                        -0.344314                    -0.101360
# 7351                        -0.740738                    -0.280088
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                                 0.030400                         -0.464761
# 1                                -0.007435                         -0.732626
# 2                                 0.177899                          0.100699
# 3                                -0.012892                          0.640011
# 4                                 0.122542                          0.693578
# ...                                    ...                               ...
# 7347                              0.829718                          0.206972
# 7348                              0.875679                         -0.879033
# 7349                             -0.266724                          0.864404
# 7350                              0.700740                          0.936674
# 7351                             -0.007739                         -0.056088
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                                -0.018446             -0.841247
# 1                                 0.703511             -0.844788
# 2                                 0.808529             -0.848933
# 3                                -0.485366             -0.848649
# 4                                -0.615971             -0.847865
# ...                                    ...                   ...
# 7347                             -0.425619             -0.791883
# 7348                              0.400219             -0.771840
# 7349                              0.701169             -0.779133
# 7350                             -0.589479             -0.785181
# 7351                             -0.616956             -0.783267
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)  subject          Activity
# 0                 0.179941             -0.058627        1          STANDING
# 1                 0.180289             -0.054317        1          STANDING
# 2                 0.180637             -0.049118        1          STANDING
# 3                 0.181935             -0.047663        1          STANDING
# 4                 0.185151             -0.043892        1          STANDING
# ...                    ...                   ...      ...               ...
# 7347              0.238604              0.049819       30  WALKING_UPSTAIRS
# 7348              0.252676              0.050053       30  WALKING_UPSTAIRS
# 7349              0.249145              0.040811       30  WALKING_UPSTAIRS
# 7350              0.246432              0.025339       30  WALKING_UPSTAIRS
# 7351              0.246809              0.036695       30  WALKING_UPSTAIRS
#
# [7352 rows x 563 columns]

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2947 entries, 0 to 2946
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 12.7+ MB

# %%
train_df.isnull().sum().sum()
# Out:
# 0

# %%
test_df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Splitting Data

# %%
y_train = train_df['Activity'].copy()
X_train = train_df.drop('Activity', axis=1).copy()

y_test  = test_df['Activity'].copy()
X_test = test_df.drop('Activity', axis=1).copy()

# %%
X_train.mean()
# Out:
# tBodyAcc-mean()-X                        0.274488
# tBodyAcc-mean()-Y                       -0.017695
# tBodyAcc-mean()-Z                       -0.109141
# tBodyAcc-std()-X                        -0.605438
# tBodyAcc-std()-Y                        -0.510938
#                                           ...
# angle(tBodyGyroJerkMean,gravityMean)    -0.005981
# angle(X,gravityMean)                    -0.489547
# angle(Y,gravityMean)                     0.058593
# angle(Z,gravityMean)                    -0.056515
# subject                                 17.413085
# Length: 562, dtype: float64

# %%
y_train.value_counts()
# Out:
# Activity
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: count, dtype: int64

# %%
num_classes = 6

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)

y_train = label_encoder.transform(y_train)
y_test = label_encoder.transform(y_test)

# %% [markdown]
# ### Scaling Data

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Modeling and Training

# %%
inputs = tf.keras.Input(shape=(X_train.shape[1], ))
x = tf.keras.layers.Dense(64, activation='relu')(inputs)
x = tf.keras.layers.Dense(64, activation='relu')(x)
outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

model = tf.keras.Model(inputs,outputs)

# %%
BATCH_SIZE = 32
EPOCHS = 25

# %%
model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=[
        tf.keras.callbacks.ModelCheckpoint('./model.keras', save_best_only=True),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=1
        )
    ]
)
# Out:
# Epoch 1/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5993 - loss: 1.0007 - val_accuracy: 0.8572 - val_loss: 0.4097 - learning_rate: 0.0010
# Epoch 2/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8777 - loss: 0.3195 - val_accuracy: 0.9055 - val_loss: 0.2545 - learning_rate: 0.0010
# Epoch 3/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9229 - loss: 0.2061 - val_accuracy: 0.9218 - val_loss: 0.2171 - learning_rate: 0.0010
# Epoch 4/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9464 - loss: 0.1542 - val_accuracy: 0.9266 - val_loss: 0.2052 - learning_rate: 0.0010
# Epoch 5/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9540 - loss: 0.1261 - val_accuracy: 0.9361 - val_loss: 0.1785 - learning_rate: 0.0010
# Epoch 6/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9636 - loss: 0.1037 - val_accuracy: 0.9375 - val_loss: 0.1815 - learning_rate: 0.0010
# Epoch 7/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9646 - loss: 0.0951 - val_accuracy: 0.9381 - val_loss: 0.1821 - learning_rate: 0.0010
# Epoch 8/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9683 - loss: 0.0851 - val_accuracy: 0.9375 - val_loss: 0.1902 - learning_rate: 0.0010
# Epoch 9/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9757 - loss: 0.0621 - val_accuracy: 0.9585 - val_loss: 0.1126 - learning_rate: 1.0000e-04
# Epoch 10/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9802 - loss: 0.0546 - val_accuracy: 0.9592 - val_loss: 0.1127 - learning_rate: 1.0000e-04
# Epoch 11/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9808 - loss: 0.0536 - val_accuracy: 0.9592 - val_loss: 0.1127 - learning_rate: 1.0000e-04
# Epoch 12/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9808 - loss: 0.0532 - val_accuracy: 0.9545 - val_loss: 0.1061 - learning_rate: 1.0000e-05
# Epoch 13/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9834 - loss: 0.0516 - val_accuracy: 0.9545 - val_loss: 0.1059 - learning_rate: 1.0000e-06
# Epoch 14/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9819 - loss: 0.0515 - val_accuracy: 0.9545 - val_loss: 0.1059 - learning_rate: 1.0000e-07
# Epoch 15/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9819 - loss: 0.0515 - val_accuracy: 0.9545 - val_loss: 0.1059 - learning_rate: 1.0000e-08
# Epoch 16/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9819 - loss: 0.0515 - val_accuracy: 0.9545 - val_loss: 0.1059 - learning_rate: 1.0000e-09
# Epoch 17/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9819 - loss: 0.0515 - val_accuracy: 0.9545 - val_loss: 0.1059 - learning_rate: 1.0000e-10
# Epoch 18/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9819 - loss: 0.0515 - val_accuracy: 0.9545 - val_loss: 0.1059 - learning_rate: 1.0000e-11
# Epoch 19/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9819 - loss: 0.0515 - val_accuracy: 0.9545 - val_loss: 0.1059 - learning_rate: 1.0000e-12
# Epoch 20/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9819 - loss: 0.0515 - val_accuracy: 0.9545 - val_loss: 0.1059 - learning_rate: 1.0000e-13
# Epoch 21/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9819 - loss: 0.0515 - val_accuracy: 0.9545 - val_loss: 0.1059 - learning_rate: 1.0000e-14
# Epoch 22/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9819 - loss: 0.0515 - val_accuracy: 0.9545 - val_loss: 0.1059 - learning_rate: 1.0000e-15
# Epoch 23/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9819 - loss: 0.0515 - val_accuracy: 0.9545 - val_loss: 0.1059 - learning_rate: 1.0000e-16
# Epoch 24/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9819 - loss: 0.0515 - val_accuracy: 0.9545 - val_loss: 0.1059 - learning_rate: 1.0000e-17
# Epoch 25/25
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9819 - loss: 0.0515 - val_accuracy: 0.9545 - val_loss: 0.1059 - learning_rate: 1.0000e-18

# %% [markdown]
# ### Results

# %%
plt.figure(figsize=(16, 10))

epochs_range = range(EPOCHS)
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(
    epochs_range,
    train_loss,
    label='Training Loss'
)

plt.plot(
    epochs_range,
    val_loss,
    label='Validation Loss'
)

plt.legend()
plt.title('Loss over time')

plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9322 - loss: 0.1771
# [0.17437198758125305, 0.9399389028549194]

# %%
model.load_weights('/kaggle/working/model.keras')

# %%
model.evaluate(X_test, y_test)
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9322 - loss: 0.1771
# [0.17437198758125305, 0.9399389028549194]
